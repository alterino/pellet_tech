# %%
import pandas as pd
extruder1 = "Unnamed: 6"

extruder2 = "Unnamed: 10"
extruder3 = "Unnamed: 14"
extruder4 = "Unnamed: 18"


extruder = extruder1
# Read the Excel file into a Pandas DataFrame
df = pd.read_excel("production.xlsx")
dates = df["Unnamed: 0"]
# Print the first five rows of the DataFrame
extruder_1_hours = df[df[extruder].notnull()]

new_df = df[df[extruder].notnull() ]

new_df = new_df.drop(new_df.index[0])
new_df['datetime'] = pd.to_datetime(new_df['Unnamed: 0'], errors='coerce')

# %%
import pandas as pd

# Assuming you have an existing DataFrame called new_df
# with extruder columns extruder1, extruder2, extruder3, extruder4

# Iterate over the extruder columns
for count, extruder in enumerate([extruder1, extruder2, extruder3, extruder4]):
    # Initialize variables for expected hours and actual hours worked
    expected_hours = 12 * len(new_df)
    actual_hours = 0

    # Iterate over each row of the DataFrame
    for _, row in new_df.iterrows():
        value = row[extruder]
        if pd.notnull(value) and 0 <= value <= 12:
            actual_hours += value

    # Compute the ratio of actual hours worked to expected hours worked
    hours_ratio = actual_hours / expected_hours

    print(f"Extruder: {count + 1}")
    print(f"Expected Hours Worked: {expected_hours} hours")
    print(f"Actual Hours Worked: {actual_hours} hours")
    print(f"Ratio of Hours worked: {hours_ratio:.2f}")
    print()
# Out:
# Extruder: 1
# Expected Hours Worked: 4008 hours
# Actual Hours Worked: 3733.5 hours
# Hours Ratio: 0.93
#
# Extruder: 2
# Expected Hours Worked: 4008 hours
# Actual Hours Worked: 3490.0 hours
# Hours Ratio: 0.87
#
# Extruder: 3
# Expected Hours Worked: 4008 hours
# Actual Hours Worked: 2150.0 hours
# Hours Ratio: 0.54
#
# Extruder: 4
# Expected Hours Worked: 4008 hours
# Actual Hours Worked: 2164.5 hours
# Hours Ratio: 0.54

# %%
import pandas as pd

# Assuming you have an existing DataFrame called new_df
# with extruder columns extruder1, extruder2, extruder3, extruder4

# Initialize variables for total expected hours and total actual hours worked
total_expected_hours = 0
total_actual_hours = 0

# Iterate over the extruder columns
for count, extruder in enumerate([extruder1, extruder2, extruder3, extruder4]):
    # Initialize variables for expected hours and actual hours worked
    expected_hours = 12 * len(new_df)
    actual_hours = 0

    # Iterate over each row of the DataFrame
    for _, row in new_df.iterrows():
        value = row[extruder]
        if pd.notnull(value) and 0 <= value <= 12:
            actual_hours += value

    # Compute the ratio of actual hours worked to expected hours worked
    hours_ratio = actual_hours / expected_hours

    # Accumulate the total expected hours and total actual hours
    total_expected_hours += expected_hours
    total_actual_hours += actual_hours

    print(f"Extruder: {count + 1}")
    print(f"Expected Hours Worked: {expected_hours} hours")
    print(f"Actual Hours Worked: {actual_hours} hours")
    print(f"Working Hours Ratio: {hours_ratio:.2f}")
    print()

# Print the totals across all extruders
print("Total across all Extruders")
print(f"Total Expected Hours Worked: {total_expected_hours} hours")
print(f"Total Actual Hours Worked: {total_actual_hours} hours")
hours_ratio = total_actual_hours / total_expected_hours
print(f"Total Working Hours Ratio: {hours_ratio:.2f}")
# Out:
# Extruder: 1
# Expected Hours Worked: 4008 hours
# Actual Hours Worked: 3733.5 hours
# Working Hours Ratio: 0.93
#
# Extruder: 2
# Expected Hours Worked: 4008 hours
# Actual Hours Worked: 3490.0 hours
# Working Hours Ratio: 0.87
#
# Extruder: 3
# Expected Hours Worked: 4008 hours
# Actual Hours Worked: 2150.0 hours
# Working Hours Ratio: 0.54
#
# Extruder: 4
# Expected Hours Worked: 4008 hours
# Actual Hours Worked: 2164.5 hours
# Working Hours Ratio: 0.54
#
# Total across all Extruders
# Total Expected Hours Worked: 16032 hours
# Total Actual Hours Worked: 11538.0 hours
# Total Working Hours Ratio: 0.72

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Plot the graph
plt.plot(new_df['datetime'], new_df['Unnamed: 6'])
plt.xlabel('Datetime')
plt.ylabel('Hours')
plt.title('Hours worked vs. Datetime')
plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility
plt.show()

# %%
import pandas as pd

# Read the CSV file into a DataFrame
extruder_data = pd.read_csv("ex1-data.csv",)

extruder_data = extruder_data.fillna(value=0)


extruder_data = extruder_data.drop(extruder_data.index[0])
# # Remove the comma from the string
# extruder_data["Extruder Pressure"] = extruder_data["Extruder Pressure"].str.replace("<null>", "0")
# extruder_data["Screw Speed Output"] = extruder_data["Screw Speed Output"].str.replace("<null>", "0")
# extruder_data["Screw Speed"] = extruder_data["Screw Speed"].str.replace("<null>", "0")

# extruder_data["Extruder Thrust"] = extruder_data["Extruder Thrust"].str.replace("<null>", "0")
# extruder_data["Feed Screw Current (Amps)"] = extruder_data["Feed Screw Current (Amps)"].str.replace("<null>", "0")
# extruder_data["Feed Screw Current (Amps)"] = extruder_data["Feed Screw Current (Amps)"].fillna(value=0)

# extruder_data["Extruder Thrust"] = extruder_data["Extruder Thrust"].fillna(value=0)

# extruder_data["Screw Speed Output"] = extruder_data["Screw Speed Output"].fillna(value=0)
extruder_data["Screw Speed Output"] = extruder_data["Screw Speed Output"].astype(float)


extruder_data["Screw Speed"] = extruder_data["Screw Speed"].astype(float)
extruder_data["Extruder Die Temp"] = extruder_data["Extruder Die Temp"].astype(str)

# Replace commas with an empty string
extruder_data["Extruder Die Temp"] = extruder_data["Extruder Die Temp"].str.replace(",", "")

# Convert the column back to numeric type, handling any conversion errors
extruder_data["Extruder Die Temp"] = pd.to_numeric(extruder_data["Extruder Die Temp"], errors="coerce")

extruder_data["Extruder Thrust"] = extruder_data["Extruder Thrust"].astype(float)


extruder_data["Feed Screw Current (Amps)"] = extruder_data["Feed Screw Current (Amps)"].astype(float)
extruder_data["Discharge Conveyor Current (Amps)"] = extruder_data["Discharge Conveyor Current (Amps)"].astype(float)

extruder_data["Discharge Conveyor Speed (%)"] = extruder_data["Discharge Conveyor Speed (%)"].astype(float)

extruder_data["Screw Speed Output"] = extruder_data["Screw Speed Output"].astype(float)
# Convert the entire column to a float


# Convert the column to string type
extruder_data["Extruder Pressure"] = extruder_data["Extruder Pressure"].astype(str)

# Replace commas with an empty string
extruder_data["Extruder Pressure"] = extruder_data["Extruder Pressure"].str.replace(",", "")

# Convert the column back to numeric type, handling any conversion errors
extruder_data["Extruder Pressure"] = pd.to_numeric(extruder_data["Extruder Pressure"], errors="coerce")
# Out:
# /tmp/ipykernel_890759/827235569.py:4: DtypeWarning: Columns (2,3,4,5,6,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   extruder_data = pd.read_csv("ex1-data.csv",)

# %%
filtered_values = extruder_data[pd.isna(extruder_data['Extruder Die Temp'])]

# %%
filtered_values
# Out:
# Empty DataFrame
# Columns: [Date and Time, Extruder Pressure, Screw Speed Output, Screw Speed, Extruder Die Temp, Extruder Thrust, Feed Screw Current (Amps), Discharge Conveyor Current (Amps), Discharge Conveyor Speed (%)]
# Index: []

# %%
extruder_data["Screw Speed"]
# Out:
# 1         25.0
# 2         25.0
# 3         25.0
# 4         25.0
# 5         25.0
#           ...
# 396437    60.0
# 396438    60.0
# 396439    60.0
# 396440    60.0
# 396441    60.0
# Name: Screw Speed, Length: 396441, dtype: float64

# %%
import pandas as pd
from sklearn.neighbors import LocalOutlierFactor
import numpy as np

def detect_outliers_larger_than(df, column_name, n_neighbors=3, contamination=0.1, threshold=None):

    column_data = df[column_name]
    # Reshape the data to have a single feature
    column_data_reshaped = column_data.values.reshape(-1, 1)

    lof = LocalOutlierFactor(n_neighbors=n_neighbors, contamination=contamination)

    # Fit the model to the column data
    lof.fit(column_data_reshaped)

    # Predict the anomaly scores
    anomaly_scores = lof.negative_outlier_factor_

    # Add the anomaly scores to the DataFrame
    df['AnomalyScore'] = anomaly_scores
    
    threshold = np.abs(df['AnomalyScore']).quantile(threshold)

    # Select the top 5% values using boolean indexing
    top_5_percent = df[np.abs(df['AnomalyScore']) > threshold]



    return top_5_percent

# %%
import pandas as pd
from sklearn.neighbors import LocalOutlierFactor

def detect_outliers(df, column_name, n_neighbors=3, contamination=0.1, threshold_lower=None, threshold_upper=None):

    column_data = df[column_name]

    # Reshape the data to have a single feature
    column_data_reshaped = column_data.values.reshape(-1, 1)

    lof = LocalOutlierFactor(n_neighbors=n_neighbors, contamination=contamination)

    # Fit the model to the column data
    lof.fit(column_data_reshaped)

    # Predict the anomaly scores
    anomaly_scores = lof.negative_outlier_factor_

    # Add the anomaly scores to the DataFrame
    df['AnomalyScore'] = anomaly_scores

    # Identify the anomalies based on the condition
    if threshold_lower is not None and threshold_upper is not None:
        threshold_lower_value = np.abs(df['AnomalyScore']).quantile(threshold_lower)
        threshold_upper_value = np.abs(df['AnomalyScore']).quantile(threshold_upper)
        
        anomalies = df[(df['AnomalyScore'].abs() > threshold_lower_value) & (df['AnomalyScore'].abs() < threshold_upper_value)]
    else:
        anomalies = df

    return anomalies

# %%
def plot_line_graph_with_collapsed_points(new_df, points_df, original, column_name, title):
    # Convert 'date' column to datetime type in new_df
    new_df['date'] = pd.to_datetime(new_df['datetime'], errors='coerce')

    # Convert 'datetime' column to datetime type in points_df
    points_df['datetime'] = pd.to_datetime(points_df['Date and Time'], errors='coerce').dt.date

    # Group points_df by 'datetime' and aggregate 'column_name' using mean
    points_df_collapsed = points_df.groupby('datetime')[column_name].mean().reset_index()

    # Plot the line graph with dates data
    fig, ax1 = plt.subplots(figsize=(20,12))
    
    # Plot the line graph on the left y-axis
    ax1.plot(new_df['date'], new_df['Unnamed: 6'], label='Hours Worked')
    ax1.set_xlabel('Date')
    ax1.set_ylabel('Hours Worked')

    # Create a second y-axis for 'Extruder Pressure' values
    ax2 = ax1.twinx()

    # Plot the 'Extruder Pressure' values on the right y-axis
    ax2.scatter(points_df_collapsed['datetime'], points_df_collapsed[column_name], color='red',
                label=f'Mean Daily {column_name}')

    # Add a plate to label the mean extruder pressure
    # for i, row in points_df_collapsed.iterrows():
    #     ax2.annotate(round(row[column_name], 2), (row['datetime'], row[column_name]),
    #                  xytext=(5, 0), textcoords='offset points', ha='left', va='bottom')
    mean_value = original[column_name].mean()
    ax2.annotate(f'{column_name} Mean: {str(round(mean_value, 2))}', (new_df['datetime'].iloc[0],
                                                                  mean_value),
                 xytext=(-200, -100), textcoords='offset points', ha='left', va='bottom', color='darkorange')
    ax2.set_ylabel(column_name)

    # Rotate x-axis labels for better visibility
    plt.xticks(rotation=45)

    # Show legend
    ax1.legend(loc='upper left')
    ax2.legend(loc='lower left')

    # Title for the plot
    plt.title(f"{title}")

    plt.show()

# %%
column_name = "Extruder Pressure"
larger_than_anomalies = detect_outliers_larger_than(extruder_data, column_name, n_neighbors=3, contamination=0.1,
                            threshold=0.995)

anomalies = detect_outliers(extruder_data, column_name, n_neighbors=3, contamination=0.1,
                            threshold_lower=.95, threshold_upper=.99)
plot_line_graph_with_collapsed_points(new_df, larger_than_anomalies, extruder_data, column_name, f"Upper Range {column_name} Anomalies")
plot_line_graph_with_collapsed_points(new_df, anomalies, extruder_data, column_name, f"Upper Range {column_name} Anomalies")
# Out:
# /tmp/ipykernel_890759/3699381501.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   points_df['datetime'] = pd.to_datetime(points_df['Date and Time'], errors='coerce').dt.date
# /tmp/ipykernel_890759/3699381501.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   points_df['datetime'] = pd.to_datetime(points_df['Date and Time'], errors='coerce').dt.date

# %%
column_name = "Screw Speed Output"
larger_than_anomalies = detect_outliers_larger_than(extruder_data, column_name, n_neighbors=3, contamination=0.1,
                            threshold=0.99)

anomalies = detect_outliers(extruder_data, column_name, n_neighbors=3, contamination=0.1,
                            threshold_lower=.95, threshold_upper=.99)
plot_line_graph_with_collapsed_points(new_df, larger_than_anomalies, extruder_data, column_name, f"Upper Range {column_name} Anomalies")
plot_line_graph_with_collapsed_points(new_df, anomalies, extruder_data, column_name, f"Upper Range {column_name} Anomalies")
# Out:
# /tmp/ipykernel_890759/3699381501.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   points_df['datetime'] = pd.to_datetime(points_df['Date and Time'], errors='coerce').dt.date

# %%
column_name = "Screw Speed"
larger_than_anomalies = detect_outliers_larger_than(extruder_data, column_name, n_neighbors=3, contamination=0.1,
                            threshold=0.99)

anomalies = detect_outliers(extruder_data, column_name, n_neighbors=3, contamination=0.1,
                            threshold_lower=.95, threshold_upper=.99)
plot_line_graph_with_collapsed_points(new_df, larger_than_anomalies, extruder_data, column_name, f"Upper Range {column_name} Anomalies")
plot_line_graph_with_collapsed_points(new_df, anomalies, extruder_data, column_name, f"Upper Range {column_name} Anomalies")

# %%
column_name = "Extruder Die Temp"
larger_than_anomalies = detect_outliers_larger_than(extruder_data, column_name, n_neighbors=3, contamination=0.1,
                            threshold=0.99)

anomalies = detect_outliers(extruder_data, column_name, n_neighbors=3, contamination=0.1,
                            threshold_lower=.00, threshold_upper=.99)
plot_line_graph_with_collapsed_points(new_df, larger_than_anomalies, extruder_data, column_name, f"Upper Range {column_name} Anomalies")
plot_line_graph_with_collapsed_points(new_df, anomalies, extruder_data, column_name, f"Upper Range {column_name} Anomalies")
# Out:
# /tmp/ipykernel_890759/3699381501.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   points_df['datetime'] = pd.to_datetime(points_df['Date and Time'], errors='coerce').dt.date
# /tmp/ipykernel_890759/3699381501.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   points_df['datetime'] = pd.to_datetime(points_df['Date and Time'], errors='coerce').dt.date

# %%
column_name = "Extruder Thrust"
larger_than_anomalies = detect_outliers_larger_than(extruder_data, column_name, n_neighbors=3, contamination=0.1,
                            threshold=0.99)

anomalies = detect_outliers(extruder_data, column_name, n_neighbors=3, contamination=0.1,
                            threshold_lower=.00, threshold_upper=.99)
plot_line_graph_with_collapsed_points(new_df, larger_than_anomalies, extruder_data, column_name, f"Upper Range {column_name} Anomalies")
plot_line_graph_with_collapsed_points(new_df, anomalies, extruder_data, column_name, f"Upper Range {column_name} Anomalies")
# Out:
# /tmp/ipykernel_890759/3699381501.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   points_df['datetime'] = pd.to_datetime(points_df['Date and Time'], errors='coerce').dt.date
# /tmp/ipykernel_890759/3699381501.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   points_df['datetime'] = pd.to_datetime(points_df['Date and Time'], errors='coerce').dt.date

# %%
column_name = "Feed Screw Current (Amps)"
larger_than_anomalies = detect_outliers_larger_than(extruder_data, column_name, n_neighbors=3, contamination=0.1,
                            threshold=0.99)

anomalies = detect_outliers(extruder_data, column_name, n_neighbors=3, contamination=0.1,
                            threshold_lower=.95, threshold_upper=.99)
plot_line_graph_with_collapsed_points(new_df, larger_than_anomalies, extruder_data, column_name, f"Upper Range {column_name} Anomalies")
plot_line_graph_with_collapsed_points(new_df, anomalies, extruder_data, column_name, f"Upper Range {column_name} Anomalies")
# Out:
# /tmp/ipykernel_890759/3699381501.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   points_df['datetime'] = pd.to_datetime(points_df['Date and Time'], errors='coerce').dt.date

# %%
column_name = "Discharge Conveyor Current (Amps)"
larger_than_anomalies = detect_outliers_larger_than(extruder_data, column_name, n_neighbors=3, contamination=0.1,
                            threshold=0.99)

anomalies = detect_outliers(extruder_data, column_name, n_neighbors=3, contamination=0.1,
                            threshold_lower=.95, threshold_upper=.99)
plot_line_graph_with_collapsed_points(new_df, larger_than_anomalies, extruder_data, column_name, f"Upper Range {column_name} Anomalies")
plot_line_graph_with_collapsed_points(new_df, anomalies, extruder_data, column_name, f"Upper Range {column_name} Anomalies")

# %%
column_name = "Discharge Conveyor Speed (%)"
larger_than_anomalies = detect_outliers_larger_than(extruder_data, column_name, n_neighbors=3, contamination=0.1,
                            threshold=0.99)

anomalies = detect_outliers(extruder_data, column_name, n_neighbors=3, contamination=0.1,
                            threshold_lower=.95, threshold_upper=.99)
plot_line_graph_with_collapsed_points(new_df, larger_than_anomalies, extruder_data, column_name, f"Upper Range {column_name} Anomalies")
plot_line_graph_with_collapsed_points(new_df, anomalies, extruder_data, column_name, f"Upper Range {column_name} Anomalies")

# %%
plot_line_graph_with_collapsed_points(new_df, larger_than_anomalies, extruder_data, column_name, f"Upper Range {column_name} Anomalies")
plot_line_graph_with_collapsed_points(new_df, anomalies, extruder_data, column_name, f"Upper Range {column_name} Anomalies")
# Out:
# 1         75.7
# 2         75.7
# 3         75.7
# 4         75.7
# 5         75.7
#           ...
# 396437    40.0
# 396438    40.0
# 396439    40.0
# 396440    40.0
# 396441    40.0
# Name: Discharge Conveyor Speed (%), Length: 396441, dtype: float64
# 75.92960188275178 test
# 1         75.7
# 2         75.7
# 3         75.7
# 4         75.7
# 5         75.7
#           ...
# 396437    40.0
# 396438    40.0
# 396439    40.0
# 396440    40.0
# 396441    40.0
# Name: Discharge Conveyor Speed (%), Length: 396441, dtype: float64
# 75.92960188275178 test
