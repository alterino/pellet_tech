# %%
# significant dates by extruder


# extruder 1 shutdown dates
ext_1_shutdowns = [
    ('11/15/2022', 'High pressure slow downs'),
    ('12/12/2022', 'replaced tubes and cleaned dies'),
]

# extruder 2 shutdown dates
ext_2_shutdowns = [
    ('11/15/2022', 'High pressure slow downs'),
    ('12/13/2022', 'cleaned plant 2 produced super sacks'),
]
# extruder 3 shutdown dates
ext_3_shutdowns = [
    ('11/15/2022', 'High pressure slow downs'),
    ('')
]
# extruder 4 shutdown dates
ext_4_shutdowns = [
    ('11/15/2022', 'High pressure slow downs'),
    ('')
]

general_dates_oi = [
    ('11/16/2022', 'running high pressures'),
    ('11/17/2022', 'running high pressures'),
    ('11/18/2022', 'running high pressures extruder 3'),
    ('11/21/2022', 'running high pressures'),
    ('11/22/2022', 'running high pressures'),
    ('11/25/2022', 'running high pressures'),
    ('11/26/2022', 'running high pressures'),
    ('11/27/2022', 'running high pressures'),
    ('11/28/2022', 'everything ran good'),
    ('12/29/2022', 'everything ran good'),
    ('12/02/2022', 'running high 5000s',
    ('12/03/2022', 'running high 5000s'),
    ('12/04/2022', 'running high pressures'),
     ('12/04/2022', 'running high pressures'),
     ('12/05/2022', 'running high pressures'),
     ('12/06/2022', 'running high pressures'),
     ('12/07/2022', 'running high pressures'),
     ('12/08/2022', 'running high pressures'),
     ('12/09/2022', 'running high pressures'),
     ('12/10/2022', 'running high pressures'),
     ('12/11/2022', 'running high pressures'),
     ('12/11/2022', 'pressure came down a little'),
     ('12/12/2022', 'everything ran good'),
     ('12/12/2022', 'everything ran good'),
     ('12/12/2022', 'everything ran good'),

]

misc_events = [
    ('11/20/2022', 'lost DDG flow to p-2'),
]
